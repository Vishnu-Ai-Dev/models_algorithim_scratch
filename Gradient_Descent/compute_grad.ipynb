# %%
import numpy as np

X = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 6, 8, 10])

w, b = 0.0, 0.0
learning_rate = 0.01
epoch = 1000
m = len(X)

for epoch in range(epochs):
    y_pred = w * X + b          # forward pass
    error = y_pred - y

    dw = (1/m) * np.sum(error * X)   # gradient wrt w
    db = (1/m) * np.sum(error)       # gradient wrt b

    w -= learning_rate * dw
    b -= learning_rate * db

print(f"w = {w}, b = {b}")
