# %%
import numpy as np
X_train=np.array([2000, 3000, 4000, 5000, 6000])
Y_train=np.array([100, 150, 200, 250, 300]) 
X_train=np.c_[X_train,X_train**2]

# %%
def compute_gradient(X,y,w,b):
    m,n=X.shape[1]
    dj_dw=0
    dj_db=0

    #predictions

    for i in range(m):
        prediction=np.dot(X[i],w)+b
        error=prediction-y[i]


    #gradient calculation
    
        for j in range(n):
            dj_dw[j]+=error*X[i][j]

    dj_dw/=m
    dj_db/=m

    return dj_dw, dj_db
